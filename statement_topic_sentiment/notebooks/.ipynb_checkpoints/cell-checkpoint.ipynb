# %% [markdown]
# ### Cell

# %%
import ast
import json
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import torch
import warnings
warnings.filterwarnings('ignore')
from collections import defaultdict, Counter
from matplotlib.cm import get_cmap
from matplotlib.colors import to_hex
from tqdm import tqdm

# %%
dataset_name = "Cell"
dataset_dir = "/data/common/RecommendationDatasets/{dataset_name}_Amazon14/topics/".format(dataset_name=dataset_name)

topics = [
    "battery",
    "camera",
    "display",
    "durability",
    "performance",
    "price",
    "service",
    "software",
    "specs",
    "usability",
]
sentiments = [
    "positive",
    "negative",
    "neutral"
]

topics.sort()
print(topics)
with open(os.path.join(dataset_dir, "topics.json"), "w") as f:
    json.dump(topics, f)
# Out:
# ['battery', 'camera', 'display', 'durability', 'performance', 'price', 'service', 'software', 'specs', 'usability']

# %%
data_df = pd.read_csv(os.path.join(dataset_dir, "statement.csv"))
data_df.head()
# Out:
#   helpful   reviewTime  rating   timestamp  \
# 0  [0, 0]  05 21, 2014     4.0  1400630400
# 1  [0, 0]  01 14, 2014     5.0  1389657600
# 2  [0, 0]  06 26, 2014     5.0  1403740800
# 3  [4, 4]  10 21, 2013     4.0  1382313600
# 4  [2, 3]   02 3, 2013     5.0  1359849600
#
#                                               review         user_name  \
# 0  They look good and stick good! I just don't li...         christina
# 1  These stickers work like the review says they ...          emily l.
# 2  These are awesome and make my phone look so st...             Erica
# 3  Item arrived in great time and was in perfect ...                JM
# 4  awesome! stays on, and looks great. can be use...  patrice m rogoza
#
#           user_id     item_id                               review_title  \
# 0  A30TL5EWN6DFXT  120401325X                                 Looks Good
# 1   ASY55RVNIL0UD  120401325X                      Really great product.
# 2  A2TMXE2AFO7ONB  120401325X                             LOVE LOVE LOVE
# 3   AWJ0WZQYMYFQ4  120401325X                                      Cute!
# 4   ATX7CZYFXI1KW  120401325X  leopard home button sticker for iphone 4s
#
#                                           statements
# 0  [{'statement': 'stick well', 'topic': 'usabili...
# 1  [{'statement': 'stick on great', 'topic': 'usa...
# 2  [{'statement': 'make my phone look stylish', '...
# 3  [{'statement': 'arrived in great time', 'topic...
# 4  [{'statement': 'stays on', 'topic': 'battery',...

# %%
statement_triplets = data_df["statements"].tolist()
print(statement_triplets[0:5])
# Out:
# ["[{'statement': 'stick well', 'topic': 'usability', 'sentiment': 'positive'}, {'statement': 'rounded shape causes bumping', 'topic': 'durability', 'sentiment': 'negative'}, {'statement': 'rounded shape causes Siri to pop up', 'topic': 'usability', 'sentiment': 'negative'}, {'statement': 'will not buy similar product again', 'topic': 'price', 'sentiment': 'negative'}]", "[{'statement': 'stick on great', 'topic': 'usability', 'sentiment': 'positive'}, {'statement': 'stay on the phone', 'topic': 'durability', 'sentiment': 'positive'}, {'statement': 'are super stylish', 'topic': 'usability', 'sentiment': 'positive'}]", "[{'statement': 'make my phone look stylish', 'topic': 'usability', 'sentiment': 'positive'}, {'statement': 'has been used for almost a year', 'topic': 'durability', 'sentiment': 'neutral'}]", "[{'statement': 'arrived in great time', 'topic': 'usability', 'sentiment': 'positive'}, {'statement': 'was in perfect condition', 'topic': 'durability', 'sentiment': 'positive'}, {'statement': 'ordered due to great deal', 'topic': 'price', 'sentiment': 'positive'}, {'statement': 'expected free screen protector', 'topic': 'usability', 'sentiment': 'negative'}, {'statement': 'did not receive free screen protector', 'topic': 'usability', 'sentiment': 'negative'}]", "[{'statement': 'stays on', 'topic': 'battery', 'sentiment': 'positive'}, {'statement': 'looks great', 'topic': 'display', 'sentiment': 'positive'}, {'statement': 'can be used on multiple apple products', 'topic': 'usability', 'sentiment': 'positive'}, {'statement': 'helps to have an elevated key', 'topic': 'usability', 'sentiment': 'positive'}]"]

# %%
i = 0
for triplet_list in statement_triplets:
    triplet_list = ast.literal_eval(triplet_list)
    for triplet in triplet_list:
        statement = triplet.get("statement").lower().strip()
        topic = triplet.get("topic").lower().strip()
        sentiment = triplet.get("sentiment").lower().strip()

        print(statement.center(60), topic.center(20), sentiment.center(10), sep="|\t\t\t")
        i += 1

    if i > 40:
        break
# Out:
#                          stick well                         |			     usability      |			 positive
#                 rounded shape causes bumping                |			     durability     |			 negative
#             rounded shape causes siri to pop up             |			     usability      |			 negative
#              will not buy similar product again             |			       price        |			 negative
#                        stick on great                       |			     usability      |			 positive
#                      stay on the phone                      |			     durability     |			 positive
#                      are super stylish                      |			     usability      |			 positive
#                  make my phone look stylish                 |			     usability      |			 positive
#               has been used for almost a year               |			     durability     |			 neutral
#                    arrived in great time                    |			     usability      |			 positive
#                   was in perfect condition                  |			     durability     |			 positive
#                  ordered due to great deal                  |			       price        |			 positive
#                expected free screen protector               |			     usability      |			 negative
#            did not receive free screen protector            |			     usability      |			 negative
#                           stays on                          |			      battery       |			 positive
#                         looks great                         |			      display       |			 positive
#            can be used on multiple apple products           |			     usability      |			 positive
#                helps to have an elevated key                |			     usability      |			 positive
#               make using the home button easy               |			     usability      |			 positive
#               both my daughter and i like them              |			     usability      |			 positive
#                  would purchase them again                  |			       price        |			 positive
#                     well worth the price                    |			       price        |			 positive
#                   comes just as described                   |			     usability      |			 positive
#                     doesn't come unstuck                    |			     durability     |			 positive
#                people ask where i got it from               |			     usability      |			 neutral
#                   it's great when driving                   |			     usability      |			 positive
#                  charges phone to 20% only                  |			      battery       |			 negative
#                        waste of money                       |			       price        |			 negative
#                      has a solid build                      |			     durability     |			 positive
#                protects the phone all around                |			     usability      |			 positive
#                  has good access to buttons                 |			     usability      |			 positive
#                   battery lasts a full day                  |			      battery       |			 positive
#                   lasts from start to end                   |			      battery       |			 positive
#                       is very stylish                       |			     usability      |			 positive
#                      protects the phone                     |			     durability     |			 positive
#         has easy access to all buttons and features         |			     usability      |			 positive
#               does not affect phone reception               |			     usability      |			 positive
#                double power, just as promised               |			      battery       |			 positive
#                   fits perfectly on the s4                  |			     usability      |			 positive
#                   keeps me powered all day                  |			      battery       |			 positive
#                   fits the galaxy s4 well                   |			     usability      |			 positive
#                           is slim                           |			     durability     |			 positive
#                   doesn't add much weight                   |			     durability     |			 positive
#                   doubles the battery life                  |			      battery       |			 positive
#       can charge either the battery, the phone or both      |			      battery       |			 positive
# has an on-off switch with leds to indicate the level of charge|			      battery       |			 positive
#                         came on time                        |			      service       |			 positive
#                      was packaged well                      |			      service       |			 positive
#                   is well worth the price                   |			       price        |			 positive

# %%
def process_triplets(statement_triplets, topics, sentiments):
    correct_triplets = {}
    wrong_topics = {}
    wrong_sentiments = {}
    wrong_topics_and_sentiments = {}
    
    for triplet_list in statement_triplets:
        if not triplet_list: continue
        if type(triplet_list) != list:
            try:
                triplet_list = ast.literal_eval(triplet_list)
            except:
                continue
    
        for triplet in triplet_list:
            if not triplet: continue

            accepted_topic = True
            accepted_sentiment = True
                
            topic = triplet.get("topic")
            if topic: topic = topic.lower().replace("-", " ").replace("_", " ").strip()
            else: continue
            if topic not in topics: accepted_topic = False

            sentiment = triplet.get("sentiment")
            if sentiment: sentiment = sentiment.lower().strip()
            else: continue
            if sentiment not in sentiments: accepted_sentiment = False
        
            statement = triplet.get("statement")
            if statement: statement = statement.lower().replace("-", " ").replace("_", " ").strip()
            else: continue
            
            if not (accepted_topic or accepted_sentiment):
                if topic not in wrong_topics_and_sentiments:
                    wrong_topics_and_sentiments[topic] = {}
                if sentiment not in wrong_topics_and_sentiments[topic]:
                    wrong_topics_and_sentiments[topic][sentiment] = {}
                if statement not in wrong_topics_and_sentiments[topic][sentiment]:
                    wrong_topics_and_sentiments[topic][sentiment][statement] = 0
                wrong_topics_and_sentiments[topic][sentiment][statement] += 1

            elif accepted_sentiment and not accepted_topic:
                if topic not in wrong_topics:
                    wrong_topics[topic] = {}
                if sentiment not in wrong_topics[topic]:
                    wrong_topics[topic][sentiment] = {}
                if statement not in wrong_topics[topic][sentiment]:
                    wrong_topics[topic][sentiment][statement] = 0
                wrong_topics[topic][sentiment][statement] += 1

            elif accepted_topic and not accepted_sentiment:
                if topic not in wrong_sentiments:
                    wrong_sentiments[topic] = {}
                if sentiment not in wrong_sentiments[topic]:
                    wrong_sentiments[topic][sentiment] = {}
                if statement not in wrong_sentiments[topic][sentiment]:
                    wrong_sentiments[topic][sentiment][statement] = 0
                wrong_sentiments[topic][sentiment][statement] += 1      

            else:
                if topic not in correct_triplets:
                    correct_triplets[topic] = {}
                if sentiment not in correct_triplets[topic]:
                    correct_triplets[topic][sentiment] = {}
                if statement not in correct_triplets[topic][sentiment]:
                    correct_triplets[topic][sentiment][statement] = 0
                correct_triplets[topic][sentiment][statement] += 1    
                
    return correct_triplets, wrong_topics, wrong_sentiments, wrong_topics_and_sentiments

# %%
correct_triplets, wrong_topics, wrong_sentiments, wrong_topics_and_sentiments = process_triplets(
    statement_triplets, topics, sentiments
)

# %%
len(correct_triplets), len(wrong_topics), len(wrong_sentiments), len(wrong_topics_and_sentiments)
# Out:
# (10, 108, 2, 0)

# %%
def build_topic_stats_df(topics):
    all_topics = sorted(topics.keys())
    all_sentiments = sorted({s for t in topics.values() for s in t.keys()})
    rows = []
    for topic in all_topics:
        row = {}
        uniq_total = 0
        freq_total = 0
        for s in all_sentiments:
            counts = topics[topic].get(s, {})
            u = len(counts)
            f = int(sum(counts.values())) if counts else 0
            row[(s, "unique")] = u
            row[(s, "total")] = f
            uniq_total += u
            freq_total += f
        row[("TOTAL", "unique")] = uniq_total
        row[("TOTAL", "total")] = freq_total
        rows.append(row)
    cols = []
    for s in all_sentiments:
        cols.append((s, "unique"))
        cols.append((s, "total"))
    cols.extend([("TOTAL", "unique"), ("TOTAL", "total")])
    df = pd.DataFrame(rows, index=all_topics, columns=pd.MultiIndex.from_tuples(cols))
    df = df.fillna(0).astype(int)
    return df

# %%
correct_triplets_df_stats = build_topic_stats_df(correct_triplets)
print(correct_triplets_df_stats)
# Out:
#             negative        neutral        positive           TOTAL
#               unique  total  unique  total   unique   total  unique   total
# battery        16348  17848   10481  10941    34890   42602   61719   71391
# camera          2936   3098    1200   1290     4985    6152    9121   10540
# display         6405   6655    3557   3764    14014   18914   23976   29333
# durability     50197  56276   13864  15091    54599   78043  118660  149410
# performance     9407  10171    2766   2926    20975   30940   33148   44037
# price          10874  13396    6198   7110    24957   44438   42029   64944
# service         6951   7537    2678   2805    11774   17881   21403   28223
# software        3013   3075    1813   1830     4079    4317    8905    9222
# specs           3320   3388    4928   5144     6124    6611   14372   15143
# usability      84159  90239   56867  60183   208786  288674  349812  439096

# %%
correct_triplets_df_stats.sum(axis=0)
# Out:
# negative  unique    193610
#           total     211683
# neutral   unique    104352
#           total     111084
# positive  unique    385183
#           total     538572
# TOTAL     unique    683145
#           total     861339
# dtype: int64

# %%
wrong_sentiments
# Out:
# {'usability': {'speculative': {'missing second tab may cause screen distortion': 1},
#   'wish': {'wish there was a fully matte version': 1,
#    'wish there was a non transparent back version': 1}},
#  'durability': {'mixed': {'durable but charging is iffy': 1}}}

# %%
wrong_topics_df_stats = build_topic_stats_df(wrong_topics)
print(wrong_topics_df_stats)
# Out:
#                   negative       neutral       positive        TOTAL
#                     unique total  unique total   unique total unique total
# accessories             20    20      22    22       44    44     86    86
# accessory               25    25      79    79      100   102    204   206
# accessory quality      381   388     222   222      632   654   1235  1264
# adapter                  1     1       0     0        1     1      2     2
# aesthetic                0     0       1     1        0     0      1     1
# ...                    ...   ...     ...   ...      ...   ...    ...   ...
# water resistance         0     0       0     0        1     1      1     1
# wfi                      1     1       0     0        1     1      2     2
# wireless                 0     0       1     1        1     1      2     2
# wireless charger         0     0       0     0        2     2      2     2
# wireless charging        1     1       0     0        0     0      1     1
#
# [108 rows x 8 columns]

# %%
wrong_topics_df_stats.sum(axis=0)
# Out:
# negative  unique    1385
#           total     1416
# neutral   unique     752
#           total      759
# positive  unique    2351
#           total     2566
# TOTAL     unique    4488
#           total     4741
# dtype: int64

# %%
(wrong_topics_df_stats.sum(axis=0) / (wrong_topics_df_stats.sum(axis=0) + correct_triplets_df_stats.sum(axis=0))) * 100
# Out:
# negative  unique    0.710275
#           total     0.664480
# neutral   unique    0.715482
#           total     0.678630
# positive  unique    0.606656
#           total     0.474186
# TOTAL     unique    0.652674
#           total     0.547409
# dtype: float64

# %%
wrong_topics_stats = wrong_topics_df_stats["TOTAL"]["unique"].to_dict()
print(wrong_topics_stats)
# Out:
# {'accessories': 86, 'accessory': 204, 'accessory quality': 1235, 'adapter': 2, 'aesthetic': 1, 'aesthetics': 14, 'appearance': 13, 'apps': 1, 'armorsuit': 3, 'audio': 1744, 'audio quality': 85, 'availability': 15, 'battery charger': 1, 'bluetooth': 2, 'brand': 6, 'branding': 1, 'browser': 1, 'build quality': 2, 'cable': 3, 'cable length': 1, 'cables': 2, 'charger': 105, 'charging': 2, 'color': 43, 'compactness': 3, 'comparison': 1, 'compatibility': 171, 'connectivity': 9, 'construction': 2, 'control': 1, 'controls': 3, 'convenience': 1, 'delivery': 10, 'description': 3, 'design': 254, 'features': 13, 'fit': 2, 'flashlight': 2, 'function': 4, 'functionality': 4, 'general': 7, 'hd dock': 7, 'hd station': 1, 'headphones': 1, 'internet': 2, 'keyboard': 5, 'leather': 7, 'light': 1, 'location/web': 1, 'look': 1, 'magnetic': 3, 'market': 1, 'marketing': 2, 'media': 4, 'microphone': 35, 'music': 2, 'music headset': 1, 'music quality': 1, 'name': 3, 'network': 1, 'neutral': 1, 'nfc': 11, 'noise': 2, 'noise canceling': 3, 'noise cancellation': 5, 'noise isolation': 1, 'noise reduction': 3, 'none': 14, 'os': 1, 'overall': 17, 'packaging': 3, 'pairing': 1, 'pen': 4, 'phone': 1, 'practical': 2, 'product': 3, 'quality': 5, 'radio': 4, 'range': 16, 'recommendation': 3, 'release': 1, 'reliability': 4, 'repair': 2, 'ringtone': 3, 'screen': 2, 'security': 2, 'size': 22, 'solar charging': 3, 'sound': 108, 'sound quality': 12, 'speaker': 17, 'storage': 1, 'style': 2, 'stylus': 22, 'technology': 6, 'toolset': 4, 'touch quality': 1, 'value': 1, 'video': 2, 'voice': 5, 'voice quality': 4, 'volume': 13, 'warranty': 2, 'water resistance': 1, 'wfi': 2, 'wireless': 2, 'wireless charger': 2, 'wireless charging': 1}

# %%
# try to assign correct topic if possible
for topic in wrong_topics:
    print(topic)
    for sent in wrong_topics[topic]:
        statements = wrong_topics[topic][sent]
        statements = list(dict(sorted(statements.items(), key=lambda x: x[1])))
        if len(statements) > 4:
            statements = statements[:4]
        print("\t", sent, ":", "\n\t\t".join(statements))
# Out:
# accessory quality
# 	 negative : might have been a larger gauge of wire
# 		the charger's retractability is not functional
# 		it takes a few minutes to retract the plug fully
# 		problem seems to be with this headset
# 	 positive : cord is longer than the one that comes with the phone
# 		covers nearly every plug i've ever needed in asia
# 		comes with manuals
# 		windscreen is great for the microphone
# 	 neutral : comes with a europe charger and a cheap plug adapter
# 		comes with two sets of earbud covers
# 		provides a short audio cable
# 		requires own usb power cable
# compatibility
# 	 negative : did not work in samsung galaxy s4
# 		don't work with my mac
# 		will not work with a mac until apple decides to fix this
# 		does not work with cingular 2125 for music streaming
# 	 positive : works well with htc mogul
# 		compatible with razr v3 phone
# 		pairs easily with phone or computer
# 		same headset works properly with computer
# 	 neutral : works better for iphone 3s and ipods 2nd gen and below
# 		ordered this for iphone 4
# 		may not work with a galaxy note 3
# 		even i use also note 3
# audio
# 	 negative : person on the other end complained about static and poor quality sound
# 		produces staticy noise when phone is more than 2 feet from earpiece
# 		produces staticy noise that is audible to others
# 		tone of voices on my end sounds a bit like a tin can phone
# 	 neutral : problem went away when using cell phone instead of headset
# 		has decent sound quality
# 		has decent mic quality
# 		sound quality is fine for the price
# 	 positive : sounded great
# 		has awsome sound
# 		way better than a fm transmitter
# 		great audio
# audio quality
# 	 positive : audio quality is fantastic
# 		has good volume
# 		has good sound quality
# 		traditional earbuds have better sound quality
# 	 negative : sound comes out of one speaker only after cable issues
# 		open earbuds have poorer sound quality
# 		open earbuds let in more ambient noise
# 		audio has distortion and quivering quality
# 	 neutral : phone only transmits audio in one ear
# 		stereo audio would play in stereo if phone transmitted it
# 		brainwavz m5s are similar to m4s
# 		bass edition iems are expected to have overpowering bass
# volume
# 	 neutral : volume is ok
# 		sometimes harder to hear in larger rooms
# 	 negative : volume with maxell product is weak
# 		volume can be a bit weak
# 		wishes it had more volume
# 		sometimes hard to hear clients on speaker
# 	 positive : are more than loud enough
# 		q2 has higher volume
# 		would be happy with a little louder volume
# 		plenty loud, with volume control on device and headphones
# none
# 	 neutral : turned down the bass on the stereo
# 		has no complaints
# 		no cons mentioned
# 		fired up the shower in my bathroom, let it run a few minutes
# 	 positive : i love it
# microphone
# 	 positive : the microphone provides sound
# 		picks up your voice extremely well
# 		picks up my voice pretty well
# 		people can hear me just fine and is clear of speech
# 	 negative : the microphone produces feedback and echo
# 		the device fails to block outside sound
# 		all 4 jabras have very poor microphone quality
# 		all 4 jabra headsets had poor microphone quality
# 	 neutral : got the ge tl26593 earset microphone by jasco
# 		a tiny amount of digitized voice but almost nothing
# 		the microphone is okay for hidden types
# design
# 	 negative : has a huge, blue orb like light on the front
# 		the light blinks in standby
# 		the light blinks when in operation
# 		the light blinks all the time
# 	 positive : improved on the razr's lines with the stylish clamshell pebl
# 		charge cable is hip
# 		connector attaches magnetically
# 		has a nice and simple design
# 	 neutral : would be cute if the m&m piece was a bit bigger
# 		is mirrored like stated
# 		design is similar to the 1940 automatic electric company's model ae40
# 		reminds me a lot of the samsung solstice/eternity series
# speaker
# 	 negative : device is too quiet at maximum volume
# 		speaker is not effective in a car with road noise
# 		found the speaker/amplification option to sound tinny/hollow
# 		sometimes, not often, the person on the other end has a hard time hearing me
# 	 neutral : speaker is only adequate in a quiet room
# 		speaker's placement may be the issue
# 		in ear type may be a better option
# 		speaker functions well
# 	 positive : nice and loud
# 		have not had any trouble hearing or wanting louder
# 		does not require screaming to be heard
# 		has a good speaker for quiet rooms
# aesthetics
# 	 positive : it's attractive in its minimalist aesthetic
# 		color options are cool
# 		aesthetics are tiny and stylish
# 		has an attractive design
# appearance
# 	 negative : looks bulky and heavy
# 		has an ugly 'lugulake' logo on the top
# 	 positive : nice orange color
# 		not overwhelming bright
# 		gets a second look
# 		looks very nice
# 	 neutral : it is a pale grey color
# 		the connectors are white
# sound
# 	 positive : has better sound quality than using my phone
# 		people can hear me without static
# 		produces decent sound
# 		has clean highs and mids
# 	 negative : has unacceptable sound quality when speaking
# 		sound quality can be too loud and have too much low end
# 		sound is not loud enough
# 		has lots of background noise
# 	 neutral : has less noticeable bass
# 		sounds fair on low to medium volume
# 		gets decently loud
# 		amplifies sound a bit
# accessories
# 	 neutral : comes with 3 different sizes of earbuds
# 		has 5 usb sync and charging cables
# 		the charger is the same model as the oem charger that came with the bold 9700
# 		comes with ear buds
# 	 positive : came with euro charger
# 		came with small adapter for american outlets
# 		can always order another set
# 		additional micro usb cord can be used
# 	 negative : does not come with its own cord and power brick
# 		must use factory one
# 		cord is oily
# 		charger does not come with trays for ipod, itouch, iphone 3 gen and 4 gen
# sound quality
# 	 positive : has good volume level
# 		has low static
# 		call quality remains good at 30 ft. range
# 		call quality remains good when moving between rooms
# 	 negative : not better than my free after rebate bluetooth
# 		sound lacks low end
# 	 neutral : sound becomes more balanced when aiming speakers into a wall
# color
# 	 positive : color was not disappointing
# 		is very vibrant
# 		color matches blue on front of phone perfectly
# 	 negative : received light pink instead of dark purple and black
# 		the received case has a pale color
# 		the case does not live up to its colorful appearance
# 		is not hot pink, but rather purple
# 	 neutral : has the same color as incredible 2 red
# 		this one is closer to fuschia than hot pink
# 		teal turned into darker teal/green
# 		green color was ok
# voice
# 	 negative : people on the other end couldn't understand
# 		voice calls have been very staticky
# 		voice is not clear
# 	 neutral : 3 stars for voice
# 	 positive : voice is very clear
# connectivity
# 	 positive : connects quickly and easily to iphone, notebook, and media center computer
# 		easily picked up by iphone 4
# 		pairing was easy and quick
# 		connection is more steady than old samsung units
# 	 negative : used a planatronics voyager 510 that would frequently drop the connection to the phone
# 		connection range is limited to 33 feet
# 		putting headset in back pocket can cause problems
# 	 neutral : wait for 7 seconds before connecting
# technology
# 	 positive : technology is 5 stars
# 		latency is non existent with iphone
# 		latency is barely noticeable on media center pc
# 		latency improves when switched to high performance power settings
# 	 neutral : latency is mild on notebook
# 		latency is generally more a factor of processor at the sound source
# reliability
# 	 positive : would rather it was reliable
# 		has a reliable track record
# 		never lets me down
# 		is reliable
# accessory
# 	 neutral : received an official motorola charger
# 		charger has a micro usb end
# 		includes led/laser combination
# 		flashlight isn't incredibly strong
# 	 positive : cable is awesome
# 		comes with a led flashlight
# 		comes with a laser pointer
# 		has a built in flashlight
# 	 negative : comes with a 20 inch cable
# 		expected 40 inch cable
# 		cord is not included
# 		mini usb adapter does not fit due to non removable battery cover
# adapter
# 	 positive : adapter keeps up with current drain
# 	 negative : adapter gets warmer than expected
# noise isolation
# 	 positive : reminds me of plugging ears and saying 'i'm not listening'
# delivery
# 	 positive : arrived early
# 		arrived as promised
# 		came ahead of time
# 		ordered on a monday, delivery was on thursday
# 	 neutral : limir stylus arrives in a few days
# 		blue phone arrived last
# 		red phone arrived second
# features
# 	 neutral : has a noise canceling button
# 		has an fm radio
# 		removes features you don't need
# 	 positive : has a built in radio
# 		has a built in fm
# 		features a built in fm radio
# 		has a built in fm radio
# 	 negative : features should be functional, not gimmicky
# media
# 	 positive : works well for audio
# 		has a great built in fm tuner
# 		has easy to use internet radio feed
# 		loads with content
# browser
# 	 positive : browser renders pages perfectly
# charger
# 	 positive : works great
# 		charger is longer than average
# 		charger works excellently
# 		2.1 amp charger charges phone quickly
# 	 negative : is not a fast charger
# 		does not have usb charging option
# 		charger stopped working
# 		had to use a different charger
# 	 neutral : has pull out prongs to plug into standard duplex outlet
# 		has a usb slot on one end
# 		is a universal cell phone battery charger
# 		charger not mentioned
# name
# 	 positive : labels on skateboards, snowboards, and bmx bikes are sensible
# 		lives up to its name
# 	 negative : labels on bluetooth earpieces are not sensible
# size
# 	 negative : is shorter than anticipated
# 		lacks in size
# 		it's a huge phone
# 	 neutral : is huge, roughly double the size of the stock battery
# 		note ii is big, but not too big
# 		is as big as two thumbs on each other at the outlet end
# 		is 4.5x3x1 inches in size
# 	 positive : takes up very little space
# 		is smaller than it appears in the photos
# 		is one of the smaller battery packs i have seen
# 		is smaller than samsung note 2 phone
# comparison
# 	 neutral : plantronics 520 is slightly noisier in fan test
# cables
# 	 negative : comes with only a usb charging cable
# 		requires iphone 110w female adapter
# radio
# 	 negative : fm radio doesn't work with this
# 	 positive : has radio
# 		radio function works nicely
# 		picks up a lot more stations than expected
# quality
# 	 positive : product was in perfect order
# 		quality seemed excellent
# 	 negative : has a low quality
# 		is not very high quality
# 		had buzzing on the right side
# touch quality
# 	 positive : provides a great tactile feeling
# style
# 	 positive : has blue lights
# 	 negative : does not look good
# compactness
# 	 neutral : is slightly bigger than a deck of cards
# 		weighs 230 grams or about 8 ounces
# 		weighs the same as 1 cup of water
# music
# 	 positive : google music is a savior
# 		camera, video, music, apps, and battery life are incredible
# warranty
# 	 neutral : company sent papers with 90 day warranty
# 	 positive : has 100% lifetime replacement
# repair
# 	 positive : product fixed it
# 		button works fine now
# product
# 	 positive : excellent product
# 		number one product
# 		item is great
# availability
# 	 negative : found all stores out of stock
# 		back order was 3 6 weeks
# 		droidx was sold out at local stores
# 		droidx was out of stock at amazon for 5 7 weeks
# 	 neutral : can be found in any store
# 		in short supply
# 		was not available at the time
# 		had hoped to get gray one but it was out
# functionality
# 	 positive : works perfectly
# 		automatically charges when a usb cable is plugged in
# 	 neutral : has limited functionality
# 		turns off if no charge is being made within 3 seconds
# range
# 	 positive : range is at least 15 feet
# 		range is about 30 feet
# 		can walk around my apartment without losing signal
# 		can get to 10 to 12 feet away before dropping a signal
# 	 negative : has a limited range
# 		range is affected by obstacles
# 		does not reach 300 ft range as advertised
# 		range is horrible
# 	 neutral : range is one thing i have seen comments on a lot
# 		range issues were seen in some negative comments
# bluetooth
# 	 positive : pairing was simple
# 	 negative : bluetooth does not draw enough current
# pairing
# 	 positive : connects to my android phone
# brand
# 	 positive : nokia is nokia
# 		motorola stands for quality
# 		htc brand
# 		has a name brand like lg, motorola, plantronics, and others
# 	 neutral : product says samsung
# phone
# 	 negative : phone calls are not great
# stylus
# 	 neutral : has a round soft tip
# 		has a 1/4 inch diameter tip
# 		wishes it was a bit longer like a pen
# 		has a metal mesh and rounded tip
# 	 negative : lacks precision for technical drawings
# 		does not have the best stylus
# 		stylus end is not very sensitive
# 		stylus end requires pushing hard to take
# 	 positive : works great
# 		tip is firmer
# 		this unit has a built in pen
# 		microfiber tip reduces squeaking and snagging
# overall
# 	 positive : it is a very good product
# 		would buy it again if need be
# 		i highly recommend it
# 		so far so good with everything
# 	 neutral : no huge complaints
# 	 negative : totally discontent with the product
# noise reduction
# 	 positive : noise reduction is second to none
# 		folks on the other end don't even know i'm on from a noisy location during conference calls
# 		it's much better at noise reduction than early jawbones
# music headset
# 	 positive : allows listening to pandora
# cable length
# 	 neutral : longer than apple cable (4 inches)
# packaging
# 	 neutral : packaging is labeled as 'for iphone'
# 		packaging is meant to market the product
# 	 negative : packaging is made of heavy plastic
# light
# 	 positive : has a nice kick
# control
# 	 positive : is firmer than other rubber tipped styluses
# storage
# 	 positive : holds other files like video/pics
# keyboard
# 	 negative : keys are not back lit
# 		buttons are small
# 		requires strong fingernails to press buttons
# 	 neutral : features metallic keyboard
# 		has actual buttons that need to be pressed
# look
# 	 positive : looks elegant
# noise
# 	 neutral : not noise cancelling
# 		noise cancellation is average
# leather
# 	 neutral : split grain leather has a simulated grain
# 		full grain leather has a natural appearance
# 	 negative : bonded leather is like particle board
# 		bonded leather is small leather bits in glue
# 		bonded leather smells terrible
# 		bonded leather looks unnatural
# marketing
# 	 neutral : headset sells itself on noise canceling
# 		travelmat is marketed as 'the only two in one charger'
# noise canceling
# 	 negative : noise canceling is overstated
# 		picks up standard noise (car, white, street, wind)
# 		noise canceling has little to no effect
# build quality
# 	 positive : speakers themselves seem good
# 	 negative : band seems a bit flimsy
# description
# 	 neutral : describes the airstash as computer memory
# 		sounds like a disk drive
# 	 positive : is actually a wifi thumb drive
# pen
# 	 positive : writes smoothly
# 		does not leave fingerprints behind
# 		pen is amazing
# 		writes nice
# fit
# 	 positive : ear buds fit well
# 	 negative : ear buds push out of ear when lifting weights
# hd dock
# 	 positive : has hdmi connectivity
# 		has 3.5mm audio jack
# 		works with razr maxx hd despite not being designed for it
# 		invokes built in alarm clock app with additional app buttons
# 	 neutral : docks phone slightly off center
# hd station
# 	 positive : has usb connectivity
# battery charger
# 	 positive : works great
# nfc
# 	 neutral : cannot comment on nfc capabilities
# 		nfc antenna is genuine oem
# 		does not know if nfc works
# 		does not need nfc
# 	 positive : nfc works fine
# 		works well
# 		work for me and my device
# 		nfc did work with this product
# 	 negative : nfc doesn't work
# 		only gets nfc to work a few times
# 		yet to find anything that's slim and provides working nfc
# ringtone
# 	 positive : has a nice and loud ringtone
# 	 negative : ring tones are all high pitched
# 		can't find a ring tone that is not high pitched
# recommendation
# 	 neutral : has a sturdier micro fiber tip recommended
# 		has a more flexible metal clip recommended
# 	 negative : would not recommend due to the broken pin holders
# voice quality
# 	 positive : voice comes through well
# 		people hear me well
# 		voice quality is fine on my end
# 	 negative : voice quality cuts in and out for counterparts
# general
# 	 positive : indeed impressed with the handset
# 		everything else about the phone is wonderful
# 		is a great product
# 		everything about the phone is good
# solar charging
# 	 positive : can get full iphone charge after leaving in the sun for 5 hours
# 		got two bars and 90% boost from solar charging at the beach
# 	 neutral : had mixed results with solar charging
# cable
# 	 positive : has a great length
# 	 negative : has poor connection for the two power charging wires
# 		has to be wiggled and laid gingerly to maintain charging connection
# market
# 	 neutral : market for docking stations for galaxy note phones is not great
# location/web
# 	 negative : not being able to turn on gps is a major miss
# security
# 	 negative : lose it, someone gets it
# 		could have chosen to add more security to the pairing process
# armorsuit
# 	 negative : requires 12 24 hours of phone downtime after installation
# 	 neutral : wet installation is responsible for permanent adhesion
# 	 positive : wet installation prevents bubbles
# magnetic
# 	 positive : magnet works great
# 		magnet is powerful
# 		magnet has a smooth, silky, rubberized coating
# value
# 	 positive : 3 of them for the price
# branding
# 	 neutral : attempting to present an air of sophistication around a brand known for practicality
# neutral
# 	 neutral : is a computer science major
# function
# 	 neutral : functions are 5 stars, except for charging
# 		only 1 led light indicates what it's doing
# 	 positive : can connect without any problem
# 		has no problems with function
# wireless
# 	 neutral : has a range of about 25 feet before signal degradation
# 	 positive : wireless/bluetooth option is fantastic
# release
# 	 neutral : released after blueant's embrace headset
# headphones
# 	 neutral : reaches from ears to belly button
# video
# 	 negative : notices synchronization lag for video files
# 		local videos have 1/3 second lag
# charging
# 	 negative : does not charge device when cable is first plugged into port #1
# 		requires moving usb cable to port #2 for charging
# internet
# 	 negative : internet features are a bit lame and cumbersome
# 	 neutral : internet is not my primary concern
# music quality
# 	 neutral : listens to various music genres
# wireless charger
# 	 positive : works just fine
# 		no issues with the case on during charging
# aesthetic
# 	 neutral : is not as minimalist as a previous cover
# apps
# 	 positive : camera, video, music, apps, and battery life are incredible
# os
# 	 positive : camera, video, music, apps, and battery life are incredible
# controls
# 	 negative : volume control is beyond poor
# 		requires multiple swipes to adjust volume
# 		many swipes are required to adjust volume
# toolset
# 	 negative : two blue tools are not very durable
# 		plastic tools will break when trying to remove battery
# 		tools were not magnetic, making screw removal/replacement difficult
# 	 positive : rest of tools worked great
# noise cancellation
# 	 negative : built in noise cancellation is not significant and doesn't justify the price
# 		noise cancellation is not as good as full size headsets
# 	 positive : hsb800 handles noise better when there is no music
# 		you hear absolutely nothing that is going on around you
# 		the noise canceling is awesome
# wireless charging
# 	 negative : wireless charging is of dubious value
# construction
# 	 positive : cables seem reasonably thick
# 		good strain relief
# network
# 	 positive : has clear connections
# screen
# 	 negative : keeps fingerprints like they are going out of style
# 		picks up scratches like they are being given away for free
# wfi
# 	 negative : bad reviews relating to wifi were a concern
# 	 positive : fear of wifi issues quickly went away
# convenience
# 	 positive : has no significant drawbacks
# flashlight
# 	 positive : flashlight is a great feature
# 		flashlight is very helpful in emergency situations or camping
# practical
# 	 positive : can help diagnose problems
# 		can detect issues with usb ports
# water resistance
# 	 positive : works well in the shower

# %% [markdown]
# **Prompt** : ```The extraction of triplets (atomic statement, topic, sentiment) from reviews produced topics that are not in the accepted topics list (represented by their short name). I will give you the list of incorrect topics, with a few example statements per sentiment. Analyze the statements and estimate the closest accepted topic it can be assigned to. If no statement is provided, do not assign anything; and if an assignment is impossible, do not assign one either. Here are the examples [EXAMPLES]. Here is the list of accepted topics for the Amazon Cell dataset:
# ACCEPTED TOPICS (short name (long name): description) [TOPICS]
# You must output a JSON object; keys are the incorrect topics and their values are the short name of the accepted topic they’re assigned to. Use None for incorrect topics that are not assigned.```

# %%
gpt_assignation = {
  "accessory quality": "usability",
  "compatibility": "usability",
  "audio": "display",
  "audio quality": "display",
  "volume": "display",
  "none": None,
  "microphone": "display",
  "design": "durability",
  "speaker": "display",
  "aesthetics": "durability",
  "appearance": "durability",
  "sound": "display",
  "accessories": "usability",
  "sound quality": "display",
  "color": "durability",
  "voice": "display",
  "connectivity": "specs",
  "technology": "specs",
  "reliability": "durability",
  "accessory": "usability",
  "adapter": "usability",
  "noise isolation": "display",
  "delivery": None,
  "features": "software",
  "media": "software",
  "browser": "software",
  "charger": "usability",
  "name": None,
  "size": "durability",
  "comparison": None,
  "cables": "usability",
  "radio": "specs",
  "quality": None,
  "touch quality": "display",
  "style": "durability",
  "compactness": "durability",
  "music": "software",
  "warranty": "service",
  "repair": "service",
  "product": None,
  "availability": None,
  "functionality": "performance",
  "range": "specs",
  "bluetooth": "specs",
  "pairing": "specs",
  "brand": None,
  "phone": None,
  "stylus": "usability",
  "overall": None,
  "noise reduction": "display",
  "music headset": "usability",
  "cable length": "usability",
  "packaging": None,
  "light": "durability",
  "control": "usability",
  "storage": "specs",
  "keyboard": "usability",
  "look": "durability",
  "noise": "display",
  "leather": "durability",
  "marketing": None,
  "noise canceling": "display",
  "build quality": "durability",
  "description": None,
  "pen": "usability",
  "fit": "usability",
  "hd dock": "usability",
  "hd station": "usability",
  "battery charger": "battery",
  "nfc": "specs",
  "ringtone": "software",
  "recommendation": None,
  "voice quality": "display",
  "general": None,
  "solar charging": "battery",
  "cable": "usability",
  "market": None,
  "location/web": "specs",
  "security": "software",
  "armorsuit": "durability",
  "magnetic": "durability",
  "value": "price",
  "branding": None,
  "neutral": None,
  "function": "performance",
  "wireless": "specs",
  "release": None,
  "headphones": "usability",
  "video": "camera",
  "charging": "battery",
  "internet": "software",
  "music quality": "display",
  "wireless charger": "battery",
  "aesthetic": "durability",
  "apps": "software",
  "os": "software",
  "controls": "usability",
  "toolset": None,
  "noise cancellation": "display",
  "wireless charging": "battery",
  "construction": "durability",
  "network": "specs",
  "screen": "display",
  "wfi": "specs",
  "convenience": "usability",
  "flashlight": "usability",
  "practical": None,
  "water resistance": "durability"
}

# %%
claude_assignation = {
  "accessory quality": "usability",
  "compatibility": "specs",
  "audio": "usability",
  "audio quality": "usability",
  "volume": "usability",
  "none": None,
  "microphone": "usability",
  "design": "durability",
  "speaker": "usability",
  "aesthetics": "durability",
  "appearance": "durability",
  "sound": "usability",
  "accessories": "usability",
  "sound quality": "usability",
  "color": "durability",
  "voice": "usability",
  "connectivity": "specs",
  "technology": "performance",
  "reliability": "durability",
  "accessory": "usability",
  "adapter": "usability",
  "noise isolation": "usability",
  "delivery": "service",
  "features": "software",
  "media": "performance",
  "browser": "performance",
  "charger": "battery",
  "name": None,
  "size": "durability",
  "comparison": None,
  "cables": "usability",
  "radio": "specs",
  "quality": "durability",
  "touch quality": "display",
  "style": "durability",
  "compactness": "durability",
  "music": "performance",
  "warranty": "service",
  "repair": "service",
  "product": None,
  "availability": "service",
  "functionality": "performance",
  "range": "specs",
  "bluetooth": "specs",
  "pairing": "specs",
  "brand": None,
  "phone": None,
  "stylus": "usability",
  "overall": None,
  "noise reduction": "usability",
  "music headset": "usability",
  "cable length": "usability",
  "packaging": None,
  "light": "usability",
  "control": "usability",
  "storage": "specs",
  "keyboard": "usability",
  "look": "durability",
  "noise": "usability",
  "leather": "durability",
  "marketing": None,
  "noise canceling": "usability",
  "build quality": "durability",
  "description": None,
  "pen": "usability",
  "fit": "usability",
  "hd dock": "usability",
  "hd station": "usability",
  "battery charger": "battery",
  "nfc": "specs",
  "ringtone": "software",
  "recommendation": None,
  "voice quality": "usability",
  "general": None,
  "solar charging": "battery",
  "cable": "usability",
  "market": None,
  "location/web": "specs",
  "security": "software",
  "armorsuit": "usability",
  "magnetic": "usability",
  "value": "price",
  "branding": None,
  "neutral": None,
  "function": "performance",
  "wireless": "specs",
  "release": None,
  "headphones": "usability",
  "video": "performance",
  "charging": "battery",
  "internet": "specs",
  "music quality": "usability",
  "wireless charger": "battery",
  "aesthetic": "durability",
  "apps": "software",
  "os": "software",
  "controls": "usability",
  "toolset": "usability",
  "noise cancellation": "usability",
  "wireless charging": "battery",
  "construction": "durability",
  "network": "specs",
  "screen": "display",
  "wfi": "specs",
  "convenience": "usability",
  "flashlight": "usability",
  "practical": "usability",
  "water resistance": "durability"
}

# %%
gemini_assignation = {
  "accessory quality": "usability",
  "compatibility": "usability",
  "audio": "usability",
  "audio quality": "usability",
  "volume": "usability",
  "none": None,
  "microphone": "usability",
  "design": "usability",
  "speaker": "usability",
  "aesthetics": "usability",
  "appearance": "usability",
  "sound": "usability",
  "accessories": "usability",
  "sound quality": "usability",
  "color": "usability",
  "voice": "usability",
  "connectivity": "usability",
  "technology": "performance",
  "reliability": "durability",
  "accessory": "usability",
  "adapter": "usability",
  "noise isolation": "usability",
  "delivery": "service",
  "features": None,
  "media": "usability",
  "browser": "usability",
  "charger": "usability",
  "name": None,
  "size": "usability",
  "comparison": None,
  "cables": "usability",
  "radio": "usability",
  "quality": "usability",
  "touch quality": "display",
  "style": "usability",
  "compactness": "usability",
  "music": "usability",
  "camera, video, music, apps, and battery life are incredible": "performance",
  "warranty": "service",
  "repair": "service",
  "product": "usability",
  "availability": "service",
  "functionality": "performance",
  "range": "specs",
  "bluetooth": "specs",
  "pairing": "specs",
  "brand": None,
  "phone": "usability",
  "stylus": "usability",
  "overall": "usability",
  "noise reduction": "usability",
  "music headset": "usability",
  "cable length": "usability",
  "packaging": "usability",
  "light": "usability",
  "control": "usability",
  "storage": "specs",
  "keyboard": "usability",
  "look": "usability",
  "noise": "usability",
  "leather": "durability",
  "marketing": None,
  "noise canceling": "usability",
  "build quality": "durability",
  "description": None,
  "pen": "usability",
  "fit": "usability",
  "hd dock": "usability",
  "hd station": "usability",
  "battery charger": "battery",
  "nfc": "specs",
  "ringtone": "usability",
  "recommendation": None,
  "voice quality": "usability",
  "general": None,
  "solar charging": "battery",
  "cable": "usability",
  "market": None,
  "location/web": "specs",
  "security": "software",
  "armorsuit": "usability",
  "magnetic": "usability",
  "value": "price",
  "branding": None,
  "neutral": None,
  "function": "performance",
  "wireless": "specs",
  "release": None,
  "headphones": "usability",
  "video": "performance",
  "charging": "battery",
  "internet": "specs",
  "music quality": "usability",
  "wireless charger": "battery",
  "aesthetic": "usability",
  "apps": "software",
  "os": "software",
  "controls": "usability",
  "toolset": "usability",
  "noise cancellation": "usability",
  "wireless charging": "battery",
  "construction": "durability",
  "network": "specs",
  "screen": "display",
  "wfi": "specs",
  "convenience": "usability",
  "flashlight": "usability",
  "practical": "usability",
  "water resistance": "durability"
}

# %%
remain_wrong_topics = [t for t, n_st in wrong_topics_stats.items() if n_st >= 10]
print(remain_wrong_topics)
print(len(remain_wrong_topics))
# Out:
# ['accessories', 'accessory', 'accessory quality', 'aesthetics', 'appearance', 'audio', 'audio quality', 'availability', 'charger', 'color', 'compatibility', 'delivery', 'design', 'features', 'microphone', 'nfc', 'none', 'overall', 'range', 'size', 'sound', 'sound quality', 'speaker', 'stylus', 'volume']
# 25

# %%
final_assignation = {}
for topic in wrong_topics:
    assignations = [
        gpt_assignation.get(topic, None),
        claude_assignation.get(topic, None),
        gemini_assignation.get(topic, None)
    ]
    value_set = set(assignations)
    for value in value_set:
        if value is None: continue
        if assignations.count(value) == 3:
            final_assignation[topic] = value

# %%
final_assignation
# Out:
# {'accessory quality': 'usability',
#  'accessories': 'usability',
#  'reliability': 'durability',
#  'accessory': 'usability',
#  'adapter': 'usability',
#  'cables': 'usability',
#  'touch quality': 'display',
#  'warranty': 'service',
#  'repair': 'service',
#  'functionality': 'performance',
#  'range': 'specs',
#  'bluetooth': 'specs',
#  'pairing': 'specs',
#  'stylus': 'usability',
#  'music headset': 'usability',
#  'cable length': 'usability',
#  'control': 'usability',
#  'storage': 'specs',
#  'keyboard': 'usability',
#  'leather': 'durability',
#  'build quality': 'durability',
#  'pen': 'usability',
#  'fit': 'usability',
#  'hd dock': 'usability',
#  'hd station': 'usability',
#  'battery charger': 'battery',
#  'nfc': 'specs',
#  'solar charging': 'battery',
#  'cable': 'usability',
#  'location/web': 'specs',
#  'security': 'software',
#  'value': 'price',
#  'function': 'performance',
#  'wireless': 'specs',
#  'headphones': 'usability',
#  'charging': 'battery',
#  'wireless charger': 'battery',
#  'apps': 'software',
#  'os': 'software',
#  'controls': 'usability',
#  'wireless charging': 'battery',
#  'construction': 'durability',
#  'network': 'specs',
#  'screen': 'display',
#  'wfi': 'specs',
#  'convenience': 'usability',
#  'flashlight': 'usability',
#  'water resistance': 'durability'}

# %%
extend_correct_triplets = correct_triplets.copy()
for wrong, correct in final_assignation.items():
    for sent in wrong_topics[wrong]:
        if sent not in extend_correct_triplets[correct]:
            extend_correct_triplets[correct][sent] = {}
        for statement in wrong_topics[wrong][sent]:
            if statement not in extend_correct_triplets[correct][sent]:
                extend_correct_triplets[correct][sent][statement] = 0
            extend_correct_triplets[correct][sent][statement] += wrong_topics[wrong][sent][statement]

# %%
extend_correct_triplets_df_stats = build_topic_stats_df(extend_correct_triplets)
print(extend_correct_triplets_df_stats)
# Out:
#             negative        neutral        positive           TOTAL
#               unique  total  unique  total   unique   total  unique   total
# battery        16351  17851   10482  10942    34893   42607   61726   71400
# camera          2936   3098    1200   1290     4985    6152    9121   10540
# display         6407   6657    3557   3764    14015   18915   23979   29336
# durability     50203  56282   13866  15093    54605   78052  118674  149427
# performance     9407  10171    2770   2930    20978   30944   33155   44045
# price          10874  13396    6198   7110    24958   44439   42030   64945
# service         6951   7537    2679   2806    11777   17884   21407   28227
# software        3015   3077    1813   1830     4080    4319    8908    9226
# specs           3331   3400    4935   5151     6140    6629   14406   15180
# usability      84574  90688   57180  60516   209455  289506  351209  440710

# %%
extend_correct_triplets_df_stats.sum(axis=0)
# Out:
# negative  unique    194049
#           total     212157
# neutral   unique    104680
#           total     111432
# positive  unique    385886
#           total     539447
# TOTAL     unique    684615
#           total     863036
# dtype: int64

# %%
def process_dataset(data_df, topics, corrected_topics):
    corrected_topics_list = list(corrected_topics)

    all_triplets = {}
    cleaned_statements = []
    statement_idss = []
    topic_idss = []
    sentiment_idss = []
    sentiment_map = {"positive": +1, "neutral": 0, "negative": -1}
    
    for index, triplet_list in enumerate(data_df["statements"].tolist(), start=1):
        try:
            triplet_list = ast.literal_eval(triplet_list)
        except:
            cleaned_statements.append(None)
            statement_idss.append(None)
            topic_idss.append(None)
            sentiment_idss.append(None)
            continue

        new_triplet_list = []
        statement_ids = []
        topic_ids = []
        sentiment_ids = []
        
        for triplet in triplet_list:
            if not triplet: continue

            topic = triplet.get("topic")
            if topic: topic = topic.lower().replace("-", " ").replace("_", " ").strip()
            else: continue
            if topic not in (topics + corrected_topics_list): continue
            if topic in corrected_topics_list: topic = corrected_topics[topic]

            sentiment = triplet.get("sentiment")
            if sentiment: sentiment = sentiment.lower().strip()
            if sentiment not in sentiment_map: continue
                
            statement = triplet.get("statement")
            if statement: statement = statement.lower().replace("-", " ").replace("_", " ").strip()
            else: continue

            triplet_tuple = (statement, topic, sentiment)
            if triplet_tuple not in all_triplets:
                all_triplets[triplet_tuple] = {}
                all_triplets[triplet_tuple]["id"] = len(all_triplets)
                all_triplets[triplet_tuple]["freq"] = 0
                
            all_triplets[triplet_tuple]["freq"] += 1

            topic_id = topics.index(topic)
            sentiment_id = sentiment_map[sentiment]
            statement_id = all_triplets[triplet_tuple]["id"]

            new_triplet = {"statement": statement, "topic": topic, "sentiment": sentiment}
            new_triplet_list.append(new_triplet)
            statement_ids.append(statement_id)
            topic_ids.append(topic_id)
            sentiment_ids.append(sentiment_id)

        if len(new_triplet_list) == 0:
            new_triplet_list = None
            statement_ids = None
            topic_ids = None
            sentiment_ids = None
            
        cleaned_statements.append(new_triplet_list)
        statement_idss.append(statement_ids)
        topic_idss.append(topic_ids)
        sentiment_idss.append(sentiment_ids)

        if index % 10_000 == 0:
            print("10000 samples processed...")

    print("Done!")
    n_none = cleaned_statements.count(None)
    print("Number of fails:", n_none)
    print("% of fails:", n_none/len(data_df))

    new_data_df = pd.DataFrame(data_df)
    new_data_df["statements"] = cleaned_statements
    new_data_df["statement_ids"] = statement_idss
    new_data_df["topic_ids"] = topic_idss
    new_data_df["sentiments"] = sentiment_idss
        
    columns = ["user_id", "item_id", "timestamp", "rating", "statements", "statement_ids", "topic_ids", "sentiments"]
    #new_data_df = new_data_df[columns]
    new_data_df = new_data_df.dropna(subset=columns)

    return new_data_df, all_triplets

# %%
new_data_df, all_triplets = process_dataset(data_df, topics, final_assignation)
print(new_data_df.head())
# Out:
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# 10000 samples processed...
# Done!
# Number of fails: 4245
# % of fails: 0.02183203986854489
#   helpful   reviewTime  rating   timestamp  \
# 0  [0, 0]  05 21, 2014     4.0  1400630400
# 1  [0, 0]  01 14, 2014     5.0  1389657600
# 2  [0, 0]  06 26, 2014     5.0  1403740800
# 3  [4, 4]  10 21, 2013     4.0  1382313600
# 4  [2, 3]   02 3, 2013     5.0  1359849600
#
#                                               review         user_name  \
# 0  They look good and stick good! I just don't li...         christina
# 1  These stickers work like the review says they ...          emily l.
# 2  These are awesome and make my phone look so st...             Erica
# 3  Item arrived in great time and was in perfect ...                JM
# 4  awesome! stays on, and looks great. can be use...  patrice m rogoza
#
#           user_id     item_id                               review_title  \
# 0  A30TL5EWN6DFXT  120401325X                                 Looks Good
# 1   ASY55RVNIL0UD  120401325X                      Really great product.
# 2  A2TMXE2AFO7ONB  120401325X                             LOVE LOVE LOVE
# 3   AWJ0WZQYMYFQ4  120401325X                                      Cute!
# 4   ATX7CZYFXI1KW  120401325X  leopard home button sticker for iphone 4s
#
#                                           statements         statement_ids  \
# 0  [{'statement': 'stick well', 'topic': 'usabili...          [1, 2, 3, 4]
# 1  [{'statement': 'stick on great', 'topic': 'usa...             [5, 6, 7]
# 2  [{'statement': 'make my phone look stylish', '...                [8, 9]
# 3  [{'statement': 'arrived in great time', 'topic...  [10, 11, 12, 13, 14]
# 4  [{'statement': 'stays on', 'topic': 'battery',...      [15, 16, 17, 18]
#
#          topic_ids         sentiments
# 0     [9, 3, 9, 5]    [1, -1, -1, -1]
# 1        [9, 3, 9]          [1, 1, 1]
# 2           [9, 3]             [1, 0]
# 3  [9, 3, 5, 9, 9]  [1, 1, 1, -1, -1]
# 4     [0, 2, 9, 9]       [1, 1, 1, 1]

# %%
statement_triplets = new_data_df["statements"].to_list()
len(statement_triplets)
# Out:
# 190194

# %%
correct_triplets, wrong_topics, wrong_sentiments, wrong_topics_and_sentiments = process_triplets(
    statement_triplets, topics, sentiments
)

# %%
len(correct_triplets), len(wrong_topics), len(wrong_sentiments), len(wrong_topics_and_sentiments)
# Out:
# (10, 0, 0, 0)

# %%
final_correct_triplets_df_stats = build_topic_stats_df(correct_triplets)
print(final_correct_triplets_df_stats)
# Out:
#             negative        neutral        positive           TOTAL
#               unique  total  unique  total   unique   total  unique   total
# battery        16351  17851   10482  10942    34893   42607   61726   71400
# camera          2936   3098    1200   1290     4985    6152    9121   10540
# display         6407   6657    3557   3764    14015   18915   23979   29336
# durability     50203  56282   13866  15093    54605   78052  118674  149427
# performance     9407  10171    2770   2930    20978   30944   33155   44045
# price          10874  13396    6198   7110    24958   44439   42030   64945
# service         6951   7537    2679   2806    11777   17884   21407   28227
# software        3015   3077    1813   1830     4080    4319    8908    9226
# specs           3331   3400    4935   5151     6140    6629   14406   15180
# usability      84574  90688   57180  60516   209455  289506  351209  440710

# %%
def plot_topic_sentiment_bars(
    df: pd.DataFrame,
    save_pdf_path: str | None = None,
    figsize=(11, 6.5)
):
    mpl.rcParams['axes.prop_cycle'] = plt.cycler(color=[
        "#8da0cb", "#fc8d62", "#66c2a5", "#e78ac3", "#a6d854"
    ])
    mpl.rcParams['grid.linestyle'] = ":"
    mpl.rcParams['grid.linewidth'] = 0.6
    mpl.rcParams['grid.alpha'] = 0.7
    mpl.rcParams['font.family'] = 'serif'
    mpl.rcParams['font.size'] = 12
    mpl.rcParams['legend.fontsize'] = 10
    mpl.rcParams['legend.frameon'] = False
    mpl.rcParams['axes.spines.top'] = False
    mpl.rcParams['axes.spines.right'] = False

    def get_col(df, sent, kind):
        if isinstance(df.columns, pd.MultiIndex):
            if (sent, kind) in df.columns:
                return df[(sent, kind)]
            for a, b in df.columns:
                if str(a).lower() == sent and str(b).lower() == kind:
                    return df[(a, b)]
        else:
            candidates = [
                f"{sent} {kind}",
                f"{sent}_{kind}",
                f"{sent}.{kind}",
                f"{sent.capitalize()} {kind}",
                f"{sent.capitalize()}_{kind}",
            ]
            for c in candidates:
                if c in df.columns:
                    return df[c]
            for c in df.columns:
                if sent in str(c).lower() and kind in str(c).lower():
                    return df[c]
        return pd.Series(0, index=df.index, dtype=float)

    def drop_total(df):
        if isinstance(df.columns, pd.MultiIndex):
            keep = [c for c in df.columns if str(c[0]).lower() != "total"]
            return df.loc[:, keep]
        else:
            keep = [c for c in df.columns if "total" != str(c).strip().lower()]
            return df[[c for c in df.columns if not str(c).lower().startswith("total ")]]

    df = drop_total(df).copy()
    df = df.sort_index(ascending=False)

    neg_u = get_col(df, "negative", "unique").astype(float)
    neg_t = get_col(df, "negative", "total").astype(float)
    neu_u = get_col(df, "neutral",  "unique").astype(float)
    neu_t = get_col(df, "neutral",  "total").astype(float)
    pos_u = get_col(df, "positive", "unique").astype(float)
    pos_t = get_col(df, "positive", "total").astype(float)

    fig, ax = plt.subplots(figsize=figsize)

    topics = df.index.to_list()
    y = np.arange(len(topics))

    group_height = 0.78
    n_series = 6
    bar_h = group_height / n_series

    NEG = "#d73027"
    NEU = "#377eb8"
    POS = "#1a9850"

    colors = {
        "neg_u": (NEG, 0.55),
        "neg_t": (NEG, 1.00),
        "neu_u": (NEU, 0.55),
        "neu_t": (NEU, 1.00),
        "pos_u": (POS, 0.55),
        "pos_t": (POS, 1.00),
    }

    series = [
        ("neg_u", neg_u, "Negative · Unique"),
        ("neg_t", neg_t, "Negative · Total"),
        ("neu_u", neu_u, "Neutral · Unique"),
        ("neu_t", neu_t, "Neutral · Total"),
        ("pos_u", pos_u, "Positive · Unique"),
        ("pos_t", pos_t, "Positive · Total"),
    ]

    start = y - group_height / 2 + 0.05
    for i, (key, values, label) in enumerate(series):
        c, a = colors[key]
        ax.barh(start + i * bar_h,
                values.values,
                height=bar_h * 0.92,
                label=label,
                color=c,
                alpha=a,
                edgecolor="none")

    ax.set_yticks(y)
    ax.set_yticklabels(topics)
    ax.set_xlabel("Count of statements")
    #ax.set_title("Topic × Sentiment")

    ax.grid(axis="x", which="both")
    ax.set_axisbelow(True)

    handles, labels = ax.get_legend_handles_labels()
    handles = handles[0::2] + handles[1::2]
    labels = labels[0::2] + labels[1::2]
    seen = set()
    h2, l2 = [], []
    for h, l in zip(handles, labels):
        if l not in seen:
            seen.add(l)
            h2.append(h)
            l2.append(l)
    ax.legend(h2, l2, ncols=2, loc="lower right", bbox_to_anchor=(1.0, 0.0), frameon=True)

    plt.tight_layout()

    if save_pdf_path:
        plt.savefig(save_pdf_path, dpi=300, bbox_inches="tight")
    plt.show()

# %%
os.makedirs("plots", exist_ok=True)
plot_topic_sentiment_bars(
    final_correct_triplets_df_stats, 
    os.path.join("plots", dataset_name + "_topic_sentiment_statement_distribution.pdf")
)

# %%
new_data_df.to_csv(os.path.join(dataset_dir, "processed_dataset.csv"))

# %%
all_statements = []
all_topics = []
all_sentiments = []
all_freq = []

for i, ((statement, topic, sent), (id, freq)) in enumerate(all_triplets.items()):
    all_statements.append(statement)
    all_topics.append(topic)
    all_sentiments.append(sent)
    all_freq.append(freq)
    if i % 10_000 == 0:
        print((statement, topic, sent), freq)

statement_topic_sentiment_freq_df = pd.DataFrame({
    "statement": all_statements,
    "topic": all_topics,
    "sentiment": all_sentiments,
    "frequency": all_freq
})

print(len(statement_topic_sentiment_freq_df))
# Out:
# ('stick well', 'usability', 'positive') freq
# ('quality is very poor', 'durability', 'negative') freq
# ('takes longer than regular mail', 'service', 'negative') freq
# ('does not sit well on curved dash', 'usability', 'negative') freq
# ('falls short as a speakerphone', 'usability', 'negative') freq
# ('screen covers are good', 'usability', 'positive') freq
# ('has been on the phone for a few months', 'durability', 'neutral') freq
# ('work with both zune and ipod', 'usability', 'positive') freq
# ('has a high output of 3.1amps and 15w', 'battery', 'positive') freq
# ('survives a fall', 'durability', 'positive') freq
# ('charges both together and uses external battery first', 'usability', 'positive') freq
# ('appreciated by kids', 'usability', 'positive') freq
# ('screen protector is durable', 'durability', 'positive') freq
# ('it is the second jamnbox wireless bluetooth speaker', 'specs', 'neutral') freq
# ('adds minimal bulk and weight', 'usability', 'positive') freq
# ('cover is for a white phone, but mine is black', 'usability', 'negative') freq
# ('is thin and flexible', 'durability', 'positive') freq
# ('does not compromise charging time when charging multiple devices', 'performance', 'positive') freq
# ('has a gripable design', 'usability', 'positive') freq
# ('is only suitable for smaller devices', 'performance', 'negative') freq
# ('fits well without being too bulky', 'usability', 'positive') freq
# ('are no high end headphone', 'performance', 'neutral') freq
# ('the case is not long enough', 'usability', 'negative') freq
# ('prioritizes comfort', 'usability', 'positive') freq
# ('holds a circuit board for soldering', 'usability', 'positive') freq
# ('colors are dull', 'display', 'negative') freq
# ('description does not accurately state compatibility', 'usability', 'negative') freq
# ('sound quality is crisp and clean for the money', 'performance', 'positive') freq
# ('is not flakey', 'durability', 'positive') freq
# ('gorilla glass provides better response', 'display', 'positive') freq
# ('includes a splitter cable for computer use', 'usability', 'positive') freq
# ("connector is similar to apple's cable", 'usability', 'positive') freq
# ('can re adjust without damaging the protector', 'usability', 'positive') freq
# ('really a good product', 'usability', 'positive') freq
# ('gives more hours than old one', 'battery', 'positive') freq
# ('case obstructs charging', 'usability', 'negative') freq
# ('arm makes the case heavier and thicker', 'usability', 'negative') freq
# ('works perfectly with elements case', 'usability', 'positive') freq
# ('seems to be well padded', 'usability', 'positive') freq
# ('belt clip makes the wearer look goofy', 'usability', 'negative') freq
# ('broke one of the back glass panels within a week of purchasing', 'durability', 'negative') freq
# ('goofy looking cover plug', 'usability', 'negative') freq
# ('cords from necklace are not very long', 'usability', 'neutral') freq
# ('film is coming off after a week', 'durability', 'negative') freq
# ('exceeds expectations in range', 'specs', 'positive') freq
# ('allows plugging in two usb devices simultaneously', 'usability', 'positive') freq
# ('customer support is fast and responsive', 'service', 'positive') freq
# ("the tools don't seem to add much value to this package", 'usability', 'negative') freq
# ('many chargers this size only have 2 leds', 'battery', 'neutral') freq
# ('bottom rubber lip stretches when taken in and out of holster', 'durability', 'negative') freq
# ('the competition for a slim hard shell case is limited', 'usability', 'positive') freq
# ('charges nexus 4 and iphone 4s simultaneously', 'performance', 'positive') freq
# ('cases are not too bulky', 'usability', 'positive') freq
# ('case is not foggy', 'usability', 'positive') freq
# ('could use more bling', 'usability', 'negative') freq
# ('recharges my phone four times before recharging it', 'battery', 'positive') freq
# ('true to the colors', 'usability', 'positive') freq
# ('noise cancellation feature works reasonably well', 'camera', 'positive') freq
# ('case holds good', 'durability', 'positive') freq
# ('not built for sole source of power over a long weekend', 'battery', 'negative') freq
# ('charger starts charging right away', 'usability', 'positive') freq
# ('protectors require re setting for optimal fit', 'usability', 'neutral') freq
# ('rated for 1.5a charging', 'battery', 'positive') freq
# ('has option to change colours on the case', 'usability', 'positive') freq
# ('buttons are responsive and work on the first push', 'usability', 'positive') freq
# ('case is just as sturdy and well built as others', 'durability', 'positive') freq
# ('this product is bad for business', 'service', 'negative') freq
# ('anything longer would make for a tangle', 'usability', 'negative') freq
# ('battery can be replaced when low', 'battery', 'positive') freq
# 684615

# %%
print(statement_topic_sentiment_freq_df.sample(n=10))
# Out:
#                                                 statement        topic  \
# 81939                   the rubber covers can be annoying    usability
# 190853  mother needs to call for help when wheelchair ...    usability
# 65456       allows composite audio and video to be output      display
# 208096      grandsons fought over who was going to use it    usability
# 146965                       sound is almost non existent  performance
# 143376                     works well as wired headphones    usability
# 508909                              connector is too thin   durability
# 55760                 a little small for a full grown man   durability
# 664012                protector is clear and unnoticeable      display
# 403021  power button and volume buttons feel hard to p...    usability
#
#        sentiment frequency
# 81939   negative      freq
# 190853  positive      freq
# 65456    neutral      freq
# 208096  positive      freq
# 146965  negative      freq
# 143376  positive      freq
# 508909  negative      freq
# 55760   negative      freq
# 664012  positive      freq
# 403021  negative      freq

# %%
statement_topic_sentiment_freq_df.to_csv(os.path.join(dataset_dir, "statement_topic_sentiment_freq.csv"))

# %%
def analyze_statements_dataset(df):
    print("=" * 80)
    print("STATEMENT DATASET STATISTICAL ANALYSIS")
    print("=" * 80)
    
    # General statistics
    print("\nGENERAL STATISTICS")
    print("-" * 40)
    n_users = df['user_id'].nunique()
    n_items = df['item_id'].nunique()
    n_interactions = len(df)
    
    print(f"Unique users: {n_users:,}")
    print(f"Unique items: {n_items:,}")
    print(f"Total interactions: {n_interactions:,}")
    
    # Expand statements for analysis
    expanded_data = []
    for idx, row in df.iterrows():
        user_id = row['user_id']
        item_id = row['item_id']
        statements = row['statements']
        
        if isinstance(statements, list):
            for stmt_dict in statements:
                if isinstance(stmt_dict, dict):
                    expanded_data.append({
                        'user_id': user_id,
                        'item_id': item_id,
                        'interaction_id': idx,
                        'statement': stmt_dict.get('statement', ''),
                        'topic': stmt_dict.get('topic', ''),
                        'sentiment': stmt_dict.get('sentiment', '')
                    })
    
    expanded_df = pd.DataFrame(expanded_data)
    
    if expanded_df.empty:
        print("No valid statements found in the dataset")
        return
    
    print(f"Total statements: {len(expanded_df):,}")
    print(f"Unique statements: {expanded_df['statement'].nunique():,}")
    
    # Get unique sentiments and topics
    sentiments = sorted(expanded_df['sentiment'].unique())
    topics = sorted(expanded_df['topic'].unique())
    
    print(f"Sentiments: {sentiments}")
    print(f"Topics ({len(topics)}): {topics}")
    
    # Function to calculate statistics
    def calculate_stats(data, group_by, count_by='statement', unique=True):
        if unique:
            # Count unique statements
            stats = data.groupby(group_by)[count_by].nunique()
        else:
            # Count with frequency (all statements)
            stats = data.groupby(group_by)[count_by].count()
        
        return {
            'average': stats.mean(),
            'maximum': stats.max(),
            'minimum': stats.min(),
            'median': stats.median(),
            'std': stats.std()
        }
    
    # 1. USER STATISTICS
    print("\n" + "=" * 80)
    print("USER STATISTICS")
    print("=" * 80)
    
    user_stats_results = []
    
    # Global (all sentiments)
    for unique in [True, False]:
        label = "Unique" if unique else "With frequency"
        stats = calculate_stats(expanded_df, 'user_id', unique=unique)
        user_stats_results.append({
            'Metric': f'Statements per user ({label})',
            'Sentiment': 'All',
            'Topic': 'All',
            'Average': f"{stats['average']:.2f}",
            'Maximum': f"{stats['maximum']:.0f}",
            'Minimum': f"{stats['minimum']:.0f}",
            'Median': f"{stats['median']:.2f}",
            'Std_Dev': f"{stats['std']:.2f}"
        })
    
    # By sentiment
    for sentiment in sentiments:
        sentiment_data = expanded_df[expanded_df['sentiment'] == sentiment]
        for unique in [True, False]:
            label = "Unique" if unique else "With frequency"
            if not sentiment_data.empty:
                stats = calculate_stats(sentiment_data, 'user_id', unique=unique)
                user_stats_results.append({
                    'Metric': f'Statements per user ({label})',
                    'Sentiment': sentiment,
                    'Topic': 'All',
                    'Average': f"{stats['average']:.2f}",
                    'Maximum': f"{stats['maximum']:.0f}",
                    'Minimum': f"{stats['minimum']:.0f}",
                    'Median': f"{stats['median']:.2f}",
                    'Std_Dev': f"{stats['std']:.2f}"
                })
    
    # Per user/topic
    for unique in [True, False]:
        label = "Unique" if unique else "With frequency"
        stats = calculate_stats(expanded_df, ['user_id', 'topic'], unique=unique)
        user_stats_results.append({
            'Metric': f'Statements per user/topic ({label})',
            'Sentiment': 'All',
            'Topic': 'All',
            'Average': f"{stats['average']:.2f}",
            'Maximum': f"{stats['maximum']:.0f}",
            'Minimum': f"{stats['minimum']:.0f}",
            'Median': f"{stats['median']:.2f}",
            'Std_Dev': f"{stats['std']:.2f}"
        })
    
    # Per topic/user
    for topic in topics:
        topic_data = expanded_df[expanded_df['topic'] == topic]
        for unique in [True, False]:
            label = "Unique" if unique else "With frequency"
            if not topic_data.empty:
                stats = calculate_stats(topic_data, 'user_id', unique=unique)
                user_stats_results.append({
                    'Metric': f'Statements per user for topic "{topic}" ({label})',
                    'Sentiment': 'All',
                    'Topic': topic,
                    'Average': f"{stats['average']:.2f}",
                    'Maximum': f"{stats['maximum']:.0f}",
                    'Minimum': f"{stats['minimum']:.0f}",
                    'Median': f"{stats['median']:.2f}",
                    'Std_Dev': f"{stats['std']:.2f}"
                })
    
    user_stats_df = pd.DataFrame(user_stats_results)
    print(user_stats_df.to_string(index=False))
    
    # 2. ITEM STATISTICS
    print("\n" + "=" * 80)
    print("ITEM STATISTICS")
    print("=" * 80)
    
    item_stats_results = []
    
    # Global (all sentiments)
    for unique in [True, False]:
        label = "Unique" if unique else "With frequency"
        stats = calculate_stats(expanded_df, 'item_id', unique=unique)
        item_stats_results.append({
            'Metric': f'Statements per item ({label})',
            'Sentiment': 'All',
            'Topic': 'All',
            'Average': f"{stats['average']:.2f}",
            'Maximum': f"{stats['maximum']:.0f}",
            'Minimum': f"{stats['minimum']:.0f}",
            'Median': f"{stats['median']:.2f}",
            'Std_Dev': f"{stats['std']:.2f}"
        })
    
    # By sentiment
    for sentiment in sentiments:
        sentiment_data = expanded_df[expanded_df['sentiment'] == sentiment]
        for unique in [True, False]:
            label = "Unique" if unique else "With frequency"
            if not sentiment_data.empty:
                stats = calculate_stats(sentiment_data, 'item_id', unique=unique)
                item_stats_results.append({
                    'Metric': f'Statements per item ({label})',
                    'Sentiment': sentiment,
                    'Topic': 'All',
                    'Average': f"{stats['average']:.2f}",
                    'Maximum': f"{stats['maximum']:.0f}",
                    'Minimum': f"{stats['minimum']:.0f}",
                    'Median': f"{stats['median']:.2f}",
                    'Std_Dev': f"{stats['std']:.2f}"
                })
    
    # Per item/topic
    for unique in [True, False]:
        label = "Unique" if unique else "With frequency"
        stats = calculate_stats(expanded_df, ['item_id', 'topic'], unique=unique)
        item_stats_results.append({
            'Metric': f'Statements per item/topic ({label})',
            'Sentiment': 'All',
            'Topic': 'All',
            'Average': f"{stats['average']:.2f}",
            'Maximum': f"{stats['maximum']:.0f}",
            'Minimum': f"{stats['minimum']:.0f}",
            'Median': f"{stats['median']:.2f}",
            'Std_Dev': f"{stats['std']:.2f}"
        })
    
    # Per topic/item
    for topic in topics:
        topic_data = expanded_df[expanded_df['topic'] == topic]
        for unique in [True, False]:
            label = "Unique" if unique else "With frequency"
            if not topic_data.empty:
                stats = calculate_stats(topic_data, 'item_id', unique=unique)
                item_stats_results.append({
                    'Metric': f'Statements per item for topic "{topic}" ({label})',
                    'Sentiment': 'All',
                    'Topic': topic,
                    'Average': f"{stats['average']:.2f}",
                    'Maximum': f"{stats['maximum']:.0f}",
                    'Minimum': f"{stats['minimum']:.0f}",
                    'Median': f"{stats['median']:.2f}",
                    'Std_Dev': f"{stats['std']:.2f}"
                })
    
    item_stats_df = pd.DataFrame(item_stats_results)
    print(item_stats_df.to_string(index=False))
    
    # 3. INTERACTION STATISTICS
    print("\n" + "=" * 80)
    print("INTERACTION STATISTICS")
    print("=" * 80)
    
    interaction_stats_results = []
    
    # Global (all sentiments)
    for unique in [True, False]:
        label = "Unique" if unique else "With frequency"
        stats = calculate_stats(expanded_df, 'interaction_id', unique=unique)
        interaction_stats_results.append({
            'Metric': f'Statements per interaction ({label})',
            'Sentiment': 'All',
            'Topic': 'All',
            'Average': f"{stats['average']:.2f}",
            'Maximum': f"{stats['maximum']:.0f}",
            'Minimum': f"{stats['minimum']:.0f}",
            'Median': f"{stats['median']:.2f}",
            'Std_Dev': f"{stats['std']:.2f}"
        })
    
    # By sentiment
    for sentiment in sentiments:
        sentiment_data = expanded_df[expanded_df['sentiment'] == sentiment]
        for unique in [True, False]:
            label = "Unique" if unique else "With frequency"
            if not sentiment_data.empty:
                stats = calculate_stats(sentiment_data, 'interaction_id', unique=unique)
                interaction_stats_results.append({
                    'Metric': f'Statements per interaction ({label})',
                    'Sentiment': sentiment,
                    'Topic': 'All',
                    'Average': f"{stats['average']:.2f}",
                    'Maximum': f"{stats['maximum']:.0f}",
                    'Minimum': f"{stats['minimum']:.0f}",
                    'Median': f"{stats['median']:.2f}",
                    'Std_Dev': f"{stats['std']:.2f}"
                })
    
    # Per interaction/topic
    for unique in [True, False]:
        label = "Unique" if unique else "With frequency"
        stats = calculate_stats(expanded_df, ['interaction_id', 'topic'], unique=unique)
        interaction_stats_results.append({
            'Metric': f'Statements per interaction/topic ({label})',
            'Sentiment': 'All',
            'Topic': 'All',
            'Average': f"{stats['average']:.2f}",
            'Maximum': f"{stats['maximum']:.0f}",
            'Minimum': f"{stats['minimum']:.0f}",
            'Median': f"{stats['median']:.2f}",
            'Std_Dev': f"{stats['std']:.2f}"
        })
    
    # Per topic/interaction
    for topic in topics:
        topic_data = expanded_df[expanded_df['topic'] == topic]
        for unique in [True, False]:
            label = "Unique" if unique else "With frequency"
            if not topic_data.empty:
                stats = calculate_stats(topic_data, 'interaction_id', unique=unique)
                interaction_stats_results.append({
                    'Metric': f'Statements per interaction for topic "{topic}" ({label})',
                    'Sentiment': 'All',
                    'Topic': topic,
                    'Average': f"{stats['average']:.2f}",
                    'Maximum': f"{stats['maximum']:.0f}",
                    'Minimum': f"{stats['minimum']:.0f}",
                    'Median': f"{stats['median']:.2f}",
                    'Std_Dev': f"{stats['std']:.2f}"
                })
    
    interaction_stats_df = pd.DataFrame(interaction_stats_results)
    print(interaction_stats_df.to_string(index=False))
    
    # 4. SENTIMENT AND TOPIC DISTRIBUTION
    print("\n" + "=" * 80)
    print("SENTIMENT AND TOPIC DISTRIBUTION")
    print("=" * 80)
    
    # Sentiment distribution
    sentiment_counts = expanded_df['sentiment'].value_counts()
    sentiment_unique_counts = expanded_df.groupby('sentiment')['statement'].nunique()
    
    sentiment_dist = pd.DataFrame({
        'Sentiment': sentiment_counts.index,
        'Total_Count': sentiment_counts.values,
        'Unique_Count': [sentiment_unique_counts.get(s, 0) for s in sentiment_counts.index],
        'Total_Percentage': (sentiment_counts.values / len(expanded_df) * 100),
        'Unique_Percentage': (sentiment_unique_counts.values / expanded_df['statement'].nunique() * 100)
    })
    
    print("Sentiment distribution:")
    print(sentiment_dist.round(2).to_string(index=False))
    
    # Topic distribution
    topic_counts = expanded_df['topic'].value_counts()
    topic_unique_counts = expanded_df.groupby('topic')['statement'].nunique()
    
    topic_dist = pd.DataFrame({
        'Topic': topic_counts.index,
        'Total_Count': topic_counts.values,
        'Unique_Count': [topic_unique_counts.get(t, 0) for t in topic_counts.index],
        'Total_Percentage': (topic_counts.values / len(expanded_df) * 100),
        'Unique_Percentage': (topic_unique_counts.values / expanded_df['statement'].nunique() * 100)
    })
    
    print("\nTopic distribution:")
    print(topic_dist.round(2).to_string(index=False))
    
    # 5. SENTIMENT x TOPIC CROSS-MATRIX
    print("\n" + "=" * 80)
    print("SENTIMENT x TOPIC CROSS-MATRIX")
    print("=" * 80)
    
    # With frequency
    cross_matrix_freq = pd.crosstab(expanded_df['sentiment'], expanded_df['topic'], margins=True)
    print("Matrix with frequency:")
    print(cross_matrix_freq)
    
    # Unique statements
    cross_matrix_unique = pd.crosstab(expanded_df['sentiment'], expanded_df['topic'], 
                                    values=expanded_df['statement'], aggfunc='nunique', margins=True)
    print("\nMatrix with unique statements:")
    print(cross_matrix_unique.fillna(0).astype(int))
    
    # 6. COMPREHENSIVE STATISTICS SUMMARY
    print("\n" + "=" * 80)
    print("COMPREHENSIVE STATISTICS SUMMARY")
    print("=" * 80)
    
    # Create a comprehensive summary DataFrame
    summary_stats = []
    
    # Helper function to add stats
    def add_stats(group_type, group_cols, sentiment_filter=None, topic_filter=None):
        data = expanded_df.copy()
        
        if sentiment_filter:
            data = data[data['sentiment'] == sentiment_filter]
        if topic_filter:
            data = data[data['topic'] == topic_filter]
        
        if data.empty:
            return
        
        for unique in [True, False]:
            count_type = "Unique" if unique else "Frequency"
            
            if unique:
                grouped = data.groupby(group_cols)['statement'].nunique()
            else:
                grouped = data.groupby(group_cols)['statement'].count()
            
            summary_stats.append({
                'Grouping': group_type,
                'Sentiment': sentiment_filter or 'All',
                'Topic': topic_filter or 'All',
                'Count_Type': count_type,
                'Average': round(grouped.mean(), 2),
                'Maximum': int(grouped.max()),
                'Minimum': int(grouped.min()),
                'Median': round(grouped.median(), 2),
                'Std_Dev': round(grouped.std(), 2)
            })
    
    # Add all combinations
    add_stats('Per user', ['user_id'])
    add_stats('Per user/topic', ['user_id', 'topic'])
    add_stats('Per item', ['item_id'])
    add_stats('Per item/topic', ['item_id', 'topic'])
    add_stats('Per interaction', ['interaction_id'])
    add_stats('Per interaction/topic', ['interaction_id', 'topic'])
    
    # By sentiment
    for sentiment in sentiments:
        add_stats('Per user', ['user_id'], sentiment_filter=sentiment)
        add_stats('Per item', ['item_id'], sentiment_filter=sentiment)
        add_stats('Per interaction', ['interaction_id'], sentiment_filter=sentiment)

    for topic in topics:
        add_stats('Per user', ['user_id'], topic_filter=topic)
        add_stats('Per item', ['item_id'], topic_filter=topic)
        add_stats('Per interaction', ['interaction_id'], topic_filter=topic)
    
    summary_df = pd.DataFrame(summary_stats)
    print("Comprehensive statistics summary:")
    print(summary_df.to_string(index=False))
    
    # 7. TOP CONTRIBUTORS
    print("\n" + "=" * 80)
    print("TOP CONTRIBUTORS")
    print("=" * 80)
    
    # Top users
    top_users_freq = expanded_df.groupby('user_id')['statement'].count().nlargest(5)
    top_users_unique = expanded_df.groupby('user_id')['statement'].nunique().nlargest(5)
    
    print("Top 5 users (by statement frequency):")
    for user_id, count in top_users_freq.items():
        print(f"  {user_id}: {count} statements")
    
    print("\nTop 5 users (by unique statements):")
    for user_id, count in top_users_unique.items():
        print(f"  {user_id}: {count} unique statements")
    
    # Top items
    top_items_freq = expanded_df.groupby('item_id')['statement'].count().nlargest(5)
    top_items_unique = expanded_df.groupby('item_id')['statement'].nunique().nlargest(5)
    
    print("\nTop 5 items (by statement frequency):")
    for item_id, count in top_items_freq.items():
        print(f"  {item_id}: {count} statements")
    
    print("\nTop 5 items (by unique statements):")
    for item_id, count in top_items_unique.items():
        print(f"  {item_id}: {count} unique statements")
    
    # 8. DIVERSITY STATISTICS
    print("\n" + "=" * 80)
    print("DIVERSITY STATISTICS")
    print("=" * 80)
    
    diversity_stats = []
    
    # Diversity per user (number of different topics)
    user_topic_diversity = expanded_df.groupby('user_id')['topic'].nunique()
    diversity_stats.append({
        'Metric': 'Topics per user',
        'Average': round(user_topic_diversity.mean(), 2),
        'Maximum': int(user_topic_diversity.max()),
        'Minimum': int(user_topic_diversity.min()),
        'Median': round(user_topic_diversity.median(), 2)
    })
    
    # Diversity per user (number of different sentiments)
    user_sentiment_diversity = expanded_df.groupby('user_id')['sentiment'].nunique()
    diversity_stats.append({
        'Metric': 'Sentiments per user',
        'Average': round(user_sentiment_diversity.mean(), 2),
        'Maximum': int(user_sentiment_diversity.max()),
        'Minimum': int(user_sentiment_diversity.min()),
        'Median': round(user_sentiment_diversity.median(), 2)
    })
    
    # Diversity per item
    item_topic_diversity = expanded_df.groupby('item_id')['topic'].nunique()
    diversity_stats.append({
        'Metric': 'Topics per item',
        'Average': round(item_topic_diversity.mean(), 2),
        'Maximum': int(item_topic_diversity.max()),
        'Minimum': int(item_topic_diversity.min()),
        'Median': round(item_topic_diversity.median(), 2)
    })
    
    item_sentiment_diversity = expanded_df.groupby('item_id')['sentiment'].nunique()
    diversity_stats.append({
        'Metric': 'Sentiments per item',
        'Average': round(item_sentiment_diversity.mean(), 2),
        'Maximum': int(item_sentiment_diversity.max()),
        'Minimum': int(item_sentiment_diversity.min()),
        'Median': round(item_sentiment_diversity.median(), 2)
    })
    
    diversity_df = pd.DataFrame(diversity_stats)
    print("Diversity statistics:")
    print(diversity_df.to_string(index=False))
    
    # 9. STATEMENT FREQUENCY ANALYSIS
    print("\n" + "=" * 80)
    print("STATEMENT FREQUENCY ANALYSIS")
    print("=" * 80)
    
    # Most frequent statements
    statement_freq = expanded_df['statement'].value_counts()
    print("Top 10 most frequent statements:")
    for i, (stmt, count) in enumerate(statement_freq.head(10).items(), 1):
        print(f"  {i:2d}. '{stmt[:50]}{'...' if len(stmt) > 50 else ''}' (count: {count})")
    
    # Statement length statistics
    expanded_df['statement_length'] = expanded_df['statement'].str.len()
    length_stats = expanded_df['statement_length'].describe()
    
    print(f"\nStatement length statistics:")
    print(f"  Average length: {length_stats['mean']:.1f} characters")
    print(f"  Maximum length: {length_stats['max']:.0f} characters")
    print(f"  Minimum length: {length_stats['min']:.0f} characters")
    print(f"  Median length: {length_stats['50%']:.1f} characters")
    
    print("\n" + "=" * 80)
    print("ANALYSIS COMPLETED")

# %%
analyze_statements_dataset(new_data_df)
# Out:
# ================================================================================
# STATEMENT DATASET STATISTICAL ANALYSIS
# ================================================================================
#
# GENERAL STATISTICS
# ----------------------------------------
# Unique users: 27,873
# Unique items: 10,429
# Total interactions: 190,194
